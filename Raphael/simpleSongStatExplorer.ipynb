# %%
f = open('../mxm_dataset_test.txt/mxm_dataset_test.txt', 'r')
data = f.readlines()
f.close
data = [line for line in data if line[0] != "#"]
words = [word for word in data[0].split(",")]

def songStat(song):
    wordDict = {}
    song = song.split(",")
    wordDict['track_id'] = song[0]
    wordDict['mxm_track_id'] = song[1]
    for wordStat in song[2:]:
        wordID = int(wordStat.split(":")[0])
        wordCnt = int(wordStat.split(":")[1])
        wordDict[words[wordID]] = wordCnt
    return wordDict

# %%
data[2]
# Out:
# 'TRAADFO128F92E1E91,5325944,1:79,2:66,3:15,4:7,5:8,6:9,7:5,8:5,9:4,10:57,11:5,12:4,13:2,14:3,15:2,17:1,18:6,19:1,20:56,21:4,22:3,23:2,24:1,25:5,28:6,29:3,30:2,31:2,32:5,33:6,34:4,35:3,36:4,37:2,41:2,43:2,44:3,45:4,48:1,49:2,50:1,51:2,52:5,54:2,57:2,58:3,59:1,62:1,63:2,64:1,68:1,70:1,76:1,78:8,81:1,94:2,95:3,101:1,105:1,106:1,109:3,115:3,122:2,123:1,126:1,133:1,134:1,135:1,136:1,144:1,157:1,168:1,190:2,195:1,203:1,207:2,212:1,215:1,216:3,223:1,228:1,229:1,230:1,234:1,239:1,241:2,242:1,251:1,252:1,258:1,287:1,302:1,304:2,310:1,318:1,326:2,337:1,338:1,339:2,358:1,373:1,378:7,384:2,389:2,393:1,456:1,461:1,464:1,465:1,470:2,486:51,521:2,548:1,555:2,563:1,564:1,601:1,631:1,637:1,661:1,707:1,748:1,772:1,779:1,787:1,793:2,876:1,880:1,890:1,1036:1,1037:2,1080:1,1144:1,1146:1,1180:2,1192:1,1197:1,1214:1,1260:1,1267:1,1341:1,1366:1,1368:1,1381:1,1463:1,1466:1,1520:1,1665:1,1686:1,1848:1,2011:1,2019:1,2063:1,2087:2,2189:1,2255:1,2284:1,2321:1,2397:1,2691:1,2757:1,3012:1,3032:1,3179:1,3339:1,3609
# ...

# %%
songStat(data[2])
# Out:
# {'track_id': 'TRAADFO128F92E1E91',
#  'mxm_track_id': '5325944',
#  'the': 79,
#  'you': 66,
#  'to': 15,
#  'and': 7,
#  'a': 8,
#  'me': 9,
#  'it': 5,
#  'not': 5,
#  'in': 4,
#  'my': 57,
#  'is': 5,
#  'of': 4,
#  'your': 2,
#  'that': 3,
#  'do': 2,
#  'are': 1,
#  'we': 6,
#  'am': 1,
#  'will': 56,
#  'all': 4,
#  'for': 3,
#  'no': 2,
#  'be': 1,
#  'have': 5,
#  'know': 6,
#  'this': 3,
#  'but': 2,
#  'with': 2,
#  'what': 5,
#  'just': 6,
#  'when': 4,
#  'like': 3,
#  'now': 4,
#  'que': 2,
#  'de': 2,
#  'go': 2,
#  'up': 3,
#  'oh': 4,
#  'they': 1,
#  'out': 2,
#  'down': 1,
#  'get': 2,
#  'she': 5,
#  'see': 2,
#  'never': 2,
#  'from': 3,
#  'he': 1,
#  'let': 1,
#  'make': 2,
#  'way': 1,
#  'as': 1,
#  'day': 1,
#  'y': 1,
#  'by': 8,
#  'here': 1,
#  'caus': 2,
#  'gonna': 3,
#  'un': 1,
#  'man': 1,
#  'live': 1,
#  'too': 3,
#  'whi': 3,
#  'wo': 2,
#  'still': 1,
#  'long': 1,
#  'good': 1,
#  'about': 1,
#  'some': 1,
#  'over': 1,
#  'call': 1,
#  'es': 1,
# ...
