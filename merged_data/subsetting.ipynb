# %%
import pandas as pd
import os
df = pd.read_csv("words_songs_matched.csv", sep=",")
df[(df['year'] >= 1990) & (df['year'] <= 1999)]
# Out:
#             word  count            track_id             song_id  \
# 1852           i     15  TRAABOA128F933684A  SONHGLD12AB0188D47
# 1853         the     24  TRAABOA128F933684A  SONHGLD12AB0188D47
# 1854         you      1  TRAABOA128F933684A  SONHGLD12AB0188D47
# 1855          to     19  TRAABOA128F933684A  SONHGLD12AB0188D47
# 1856         and     16  TRAABOA128F933684A  SONHGLD12AB0188D47
# ...          ...    ...                 ...                 ...
# 19045240  quanto      1  TRZZYLF128F9316CAB  SOEDLDQ12AB0180A2E
# 19045241    puoi      1  TRZZYLF128F9316CAB  SOEDLDQ12AB0180A2E
# 19045242   mentr      1  TRZZYLF128F9316CAB  SOEDLDQ12AB0180A2E
# 19045243   paura      1  TRZZYLF128F9316CAB  SOEDLDQ12AB0180A2E
# 19045244  cambia      4  TRZZYLF128F9316CAB  SOEDLDQ12AB0180A2E
#
#                    artist_id            title       artist_name  duration  \
# 1852      AR1S3NH1187B98C2BC       Our Father         Anthony B  202.4224
# ...

# %%
df[(df['year'] >= 1990) & (df['year'] <= 1999)].to_csv("words_songs_matched_90s.csv", sep=",", index=False)

# %%
import os
print("%s MB" % str(os.path.getsize("words_songs_matched_90s.csv")/1024/1024))
os.system('zip words_songs_matched_90s.zip words_songs_matched_90s.csv') #Unix-like
# Out:
# 442.26832580566406 MB
# 0
