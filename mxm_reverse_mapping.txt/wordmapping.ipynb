# %% [markdown]
# ## This notebook will do the followings:
# 1. verify the word mapping against the main song file (words_songs_matched.csv). result: one-to-one mapping between words_songs_matched.csv, the mapping file mxm_reverse_mapping.txt, the regular word, and the word stem is confirmed.
# 2. guess the language of the words w/ Google Translate API
# 3. tag stop words using nltk.corpus.stopwords

# %%
# !pip install textblob
# !pip install nltk
# !pip install iso-639
# Out:
# Requirement already satisfied: textblob in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (from nltk>=3.1->textblob) (1.12.0)
# Requirement already satisfied: nltk in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (3.4.5)
# Requirement already satisfied: six in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (from nltk) (1.12.0)
# Requirement already satisfied: iso-639 in /Users/kin/opt/anaconda3/lib/python3.7/site-packages (0.4.5)

# %%
import pandas as pd
import numpy as np
m = pd.read_csv("mxm_reverse_mapping.txt", sep="<SEP>", engine='python', names=["stem","word_m"])
m
#load wordstem <-> regular word mapping data
# Out:
#          stem   word_m
# 0         día      día
# 1        pido     pido
# 2        hatr   hatred
# 3        pide     pide
# 4      yellow   yellow
# ...       ...      ...
# 4995     yell     yell
# 4996       at       at
# 4997  confess  confess
# 4998   sincer  sincere
# 4999  richard  richard
#
# [5000 rows x 2 columns]

# %%
m.groupby('stem').agg('count').shape
#check if stem can be mapped to > 1 regular word
#still 5000 row after groupby, thus the case above does not exist
# Out:
# (5000, 1)

# %%
df = pd.read_csv('../merged_data/words_songs_matched.csv', header=0, sep=',')
df
# Out:
#             word  count            track_id             song_id  \
# 0              i      6  TRAAAAV128F421A322  SOQPWCR12A6D4FB2A3
# 1            the      4  TRAAAAV128F421A322  SOQPWCR12A6D4FB2A3
# 2            you      2  TRAAAAV128F421A322  SOQPWCR12A6D4FB2A3
# 3             to      2  TRAAAAV128F421A322  SOQPWCR12A6D4FB2A3
# 4            and      5  TRAAAAV128F421A322  SOQPWCR12A6D4FB2A3
# ...          ...    ...                 ...                 ...
# 19045327  easili      1  TRZZZZD128F4236844  SOANRDO12A81C21E36
# 19045328  disast      1  TRZZZZD128F4236844  SOANRDO12A81C21E36
# 19045329   frown      1  TRZZZZD128F4236844  SOANRDO12A81C21E36
# 19045330    teas      1  TRZZZZD128F4236844  SOANRDO12A81C21E36
# 19045331   upset      1  TRZZZZD128F4236844  SOANRDO12A81C21E36
#
#                    artist_id                             title  \
# 0         AR73AIO1187B9AD57B  A Poor Recipe For Civic Cohesion
# 1         AR73AIO1187B9AD57B  A Poor Recipe For Civic Cohesion
# 2         AR73AIO1187B9AD57B  A Poor Recipe For Civic Cohesion
# 3         AR73AIO1187B9AD57B  A Poor Recipe For Civic Cohesion
# 4         AR73AIO1187B9AD57B  A Poor Recipe For Civic Cohesion
# ...                      ...                               ...
# 19045327  ART48CP1187B9AE314          Mr. Soul (Album Version)
# 19045328  ART48CP1187B9AE314          Mr. Soul (Album Version)
# 19045329  ART48CP1187B9AE314          Mr. Soul (Album Version)
# 19045330  ART48CP1187B9AE314          Mr. Soul (Album Version)
# 19045331  ART48CP1187B9AE314          Mr. Soul (Album Version)
#
#                 artist_name   duration  year  artist_hotttnesss
# 0         Western Addiction  118.07302  2005           0.386606
# 1         Western Addiction  118.07302  2005           0.386606
# 2         Western Addiction  118.07302  2005           0.386606
# 3         Western Addiction  118.07302  2005           0.386606
# 4         Western Addiction  118.07302  2005           0.386606
# ...                     ...        ...   ...                ...
# 19045327               Rush  229.27628     0           0.546253
# 19045328               Rush  229.27628     0           0.546253
# 19045329               Rush  229.27628     0           0.546253
# 19045330               Rush  229.27628     0           0.546253
# 19045331               Rush  229.27628     0           0.546253
#
# [19045332 rows x 10 columns]

# %%
merged = pd.merge(left=m, right=df, left_on="stem", right_on="word")
(merged['stem'] == merged['word']).value_counts()
# verify if all words(stem) in the main csv exists in the mapping file
# Out:
# True    19045332
# dtype: int64

# %%
import nltk
stopwords = nltk.corpus.stopwords

# %%
stopwords.fileids()
# Out:
# ['arabic',
#  'azerbaijani',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
from textblob import TextBlob
b = TextBlob("ball")
b.detect_language()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-e72e889fa47c> in <module>
#       1 from textblob import TextBlob
#       2 b = TextBlob("ball")
# ----> 3 b.detect_language()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/textblob/blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/textblob/translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~/opt/anaconda3/lib/python3.7/site-packages/textblob/translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %% [markdown]
# ### Perform Google Translate API language guessing
# Guess window is limited to 500 rows for IP due to anonymous API call limit
#
# Result express as ISO 639-1 lang code (https://cloud.google.com/translate/docs/basic/translating-text#language-params)

# %%
#split m into list of 10. 500 rows per sub-dataframe
mlist = np.array_split(m, 10)

# %%
def language_find(text):
    try:
        return TextBlob(text).detect_language()
    except:
        return None

# %%
seg = 0
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Finland

# %%
seg = 1
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Luxembourg

# %%
seg = 2
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#France

# %%
seg = 3
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Sweden

# %%
seg = 4
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Norway

# %%
seg = 5
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Austria

# %%
seg = 6
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Italy

# %%
seg = 7
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Spain

# %%
seg = 8
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#UAE

# %%
seg = 9
mlist[seg]['lang_GT_API'] = mlist[seg]['word_m'].apply(language_find)
#Japan

# %%
mlist[seg][mlist[seg]['lang_GT_API'].isna()]
# Out:
#      stem word_m lang_GT_API
# 4525   tv     tv        None
# 4556   as     as        None
# 4559   ar     ar        None
# 4563   ku     ku        None
# 4567   va     va        None
# 4570   ve     ve        None
# 4574   vi     vi        None
# 4583   vu     vu        None
# 4640    i      i        None
# 4648    1      1        None
# 4668   já     já        None
# 4813   mä     mä        None
# 4864   ed     ed        None
# 4881                  None
# 4882   hi     hi        None
# 4883   ho     ho        None
# 4892   he     he        None
# 4895   cu     cu        None
# 4902    j      j        None
# 4945   40     40        None
# 4980    –      –        None
# 4992   là     là        None
# 4993   lá     lá        None
# 4996   at     at        None

# %%
#rebuild complete df from list of sub-df
m3 = pd.concat(mlist)

# %%
#store result df into csv
m3.to_csv("mxm_reverse_mapping_lang.csv",sep="\t",index=False)

# %%
#count null value among guess language result
m3[m3['lang_GT_API'].isna()].shape
# Out:
# (225, 3)

# %%
#check len(word_m) of null value
for i, r in m3[m3['lang_GT_API'].isna()].iterrows():
    if len(r['word_m']) >= 3:
        print(r['word_m'])

# %%
#reload df from csv
m = pd.read_csv("mxm_reverse_mapping_lang.csv", sep="\t")
m
# Out:
#          stem   word_m lang_GT_API
# 0         día      día          es
# 1        pido     pido          es
# 2        hatr   hatred          en
# 3        pide     pide          es
# 4      yellow   yellow          en
# ...       ...      ...         ...
# 4995     yell     yell          en
# 4996       at       at         NaN
# 4997  confess  confess          en
# 4998   sincer  sincere          en
# 4999  richard  richard          en
#
# [5000 rows x 3 columns]

# %%
m['lang_GT_API'].value_counts()
# Out:
# en       3168
# es        520
# fr        241
# de        218
# pt        153
# it        143
# sv         60
# nl         46
# fi         33
# ro         16
# id         16
# no         13
# ar         13
# da         11
# pl         11
# vi          9
# tr          8
# tl          6
# hu          6
# bs          6
# et          5
# zh-CN       5
# sq          4
# lt          4
# ja          4
# sl          4
# ku          4
# is          3
# la          3
# af          3
# ca          3
# lv          3
# cs          3
# el          3
# az          2
# hi          2
# bg          2
# sk          2
# mt          2
# ru          2
# ms          2
# cy          2
# so          1
# sw          1
# eu          1
# ht          1
# bn          1
# eo          1
# gl          1
# ga          1
# mi          1
# ha          1
# uz          1
# Name: lang_GT_API, dtype: int64

# %% [markdown]
# ## stop-word tagging

# %%
#overview of nltk stopwords' supported languages
#trying to see how good or how bad the support is against our list of words and guess languages
from nltk.corpus import stopwords
import iso639

def isoToLabel(code):
    return iso639.languages.get(alpha2=code[0:2]).name.lower()

supportedLang = []
unsupportedLang = []
for lang in m['lang_GT_API'][~m['lang_GT_API'].isna()].unique():
    langLabel = isoToLabel(lang)
    if langLabel in stopwords.fileids():
        supportedLang.append(langLabel)
    else:
        unsupportedLang.append(langLabel)
print("----Stop word list supported Lang----")
for langLabel in supportedLang:
    print(langLabel)
print("----Stop word list unsupported Lang----")
for langLabel in unsupportedLang:
    print(langLabel)
# Out:
# ----Stop word list supported Lang----
# spanish
# english
# german
# finnish
# french
# swedish
# italian
# hungarian
# portuguese
# dutch
# indonesian
# arabic
# norwegian
# danish
# turkish
# romanian
# azerbaijani
# russian
# ----Stop word list unsupported Lang----
# bulgarian
# latvian
# polish
# catalan
# albanian
# malay (macrolanguage)
# slovenian
# irish
# basque
# bosnian
# afrikaans
# czech
# modern greek (1453-)
# hindi
# kurdish
# hausa
# vietnamese
# tagalog
# japanese
# bengali
# slovak
# welsh
# estonian
# chinese
# uzbek
# lithuanian
# latin
# galician
# maltese
# icelandic
# esperanto
# haitian
# swahili (macrolanguage)
# somali
# maori

# %%
#tag stopword according to guess languages
def isStopWord(word, langcode):
    try:
        return word in stopwords.words(isoToLabel(langcode))
    except:
        return np.nan

m['stopword'] = m.apply(lambda row: isStopWord(row['word_m'], row['lang_GT_API']), axis=1)

# %%
#showing count of stop words
#503 stop words tagged
m['stopword'].value_counts()
# Out:
# False    4166
# True      503
# Name: stopword, dtype: int64

# %%
#showing words not evaluated
#recall: 225 of them are len() < 3
#the rest are from unsupported language
m['stopword'].isna().value_counts()
# Out:
# False    4669
# True      331
# Name: stopword, dtype: int64

# %%
m.to_csv("mxm_reverse_mapping_lang_stop.csv",sep="\t",index=False)
